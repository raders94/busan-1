# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


sales_df = pd.DataFrame({
    "advertising": [
        10, 15, 20, 25,
        12, 18, 23, 28,
        8, 14, 19, 24,
    ],
    "sales": [
        120, 155, 190, 230,
        110, 150, 185, 215,
        95, 135, 170, 205,
    ],
    "region": [
        "Seoul", "Seoul", "Seoul", "Seoul",
        "Busan", "Busan", "Busan", "Busan",
        "Daejeon", "Daejeon", "Daejeon", "Daejeon",
    ],
    "visitors": [
        850, 1020, 1180, 1350,
        780, 950, 1100, 1280,
        690, 870, 1030, 1200,
    ],
    "channel": [
        "Online", "Offline", "Online", "Offline",
        "Online", "Offline", "Online", "Offline",
        "Online", "Offline", "Online", "Offline",
    ],
})

sales_df
# Out:
#     advertising  sales   region  visitors  channel
# 0            10    120    Seoul       850   Online
# 1            15    155    Seoul      1020  Offline
# 2            20    190    Seoul      1180   Online
# 3            25    230    Seoul      1350  Offline
# 4            12    110    Busan       780   Online
# 5            18    150    Busan       950  Offline
# 6            23    185    Busan      1100   Online
# 7            28    215    Busan      1280  Offline
# 8             8     95  Daejeon       690   Online
# 9            14    135  Daejeon       870  Offline
# 10           19    170  Daejeon      1030   Online
# 11           24    205  Daejeon      1200  Offline

# %% [markdown]
# -Long form
# : 하나의 열이 하나의 변수 하나의 행이 하나의 관측값

# %%
long_sales = pd.DataFrame({
    "month": [
        "Jan", "Jan", "Jan",
        "Feb", "Feb", "Feb",
        "Mar", "Mar", "Mar",
        "Apr", "Apr", "Apr",
    ],
    "region": [
        "Seoul", "Busan", "Daejeon",
        "Seoul", "Busan", "Daejeon",
        "Seoul", "Busan", "Daejeon",
        "Seoul", "Busan", "Daejeon",
    ],
    "sales": [
        120, 100, 90,
        150, 130, 115,
        180, 160, 145,
        210, 190, 175,
    ],
})

long_sales
# Out:
#    month   region  sales
# 0    Jan    Seoul    120
# 1    Jan    Busan    100
# 2    Jan  Daejeon     90
# 3    Feb    Seoul    150
# 4    Feb    Busan    130
# 5    Feb  Daejeon    115
# 6    Mar    Seoul    180
# 7    Mar    Busan    160
# 8    Mar  Daejeon    145
# 9    Apr    Seoul    210
# 10   Apr    Busan    190
# 11   Apr  Daejeon    175

# %%
sns.lineplot(data= long_sales, x='month', y='sales',hue='region')
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %%
sns.scatterplot(data= long_sales, x='month', y='sales',hue='region')
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %% [markdown]
# -Wide form 데이터
# : 하나의 측정 변수가 여러 열로 펼쳐져 있는 형태

# %%
wide_sales = pd.DataFrame(
    {
        "Seoul": [120, 150, 180, 210],
        "Busan": [100, 130, 160, 190],
        "Daejeon": [90, 115, 145, 175],
    },
    index=["Jan", "Feb", "Mar", "Apr"],
)

wide_sales.index.name = "month"

wide_sales.T
# Out:
# month    Jan  Feb  Mar  Apr
# Seoul    120  150  180  210
# Busan    100  130  160  190
# Daejeon   90  115  145  175

# %%
sns.lineplot(data=wide_sales)
plt.show()

# %%
sns.scatterplot(data=sales_df, x='advertising',y='sales', hue= 'region')
# Out:
# <Axes: xlabel='advertising', ylabel='sales'>

# %%
sns.scatterplot(data=sales_df, x='advertising',y='sales', hue= 'region', size='visitors',style='channel')
# Out:
# <Axes: xlabel='advertising', ylabel='sales'>

# %%
fig, ax = plt.subplots(figsize=(8,6))

sns.scatterplot(data= sales_df,x='advertising',y='sales', ax=ax)
# Out:
# <Axes: xlabel='advertising', ylabel='sales'>

# %%
fig, axes= plt.subplots(nrows=1,
                ncols=2,
                figsize=(12,5))

sns.scatterplot(data= sales_df,x='advertising',y='sales', hue='region',ax=axes[0])

sns.boxplot(data= sales_df,x='region',y='sales', ax=axes[1])
#엑시스 유형
# Out:
# <Axes: xlabel='region', ylabel='sales'>

# %%
sns.relplot(data= sales_df,x='advertising',y='sales', hue='region',kind='scatter') #kind로 종류 바꾸기

# %%
sns.relplot(data= sales_df,x='advertising',y='sales', hue='region',col='channel',kind='scatter')

# %%
facet_df = sales_df.copy()

facet_df['period']=['First', 'First', 'Second', 'Second',
                    'First', 'First', 'Second', 'Second',
                    'First', 'First', 'Second', 'Second']


facet_df[['region','channel', 'period']]
# Out:
#      region  channel  period
# 0     Seoul   Online   First
# 1     Seoul  Offline   First
# 2     Seoul   Online  Second
# 3     Seoul  Offline  Second
# 4     Busan   Online   First
# 5     Busan  Offline   First
# 6     Busan   Online  Second
# 7     Busan  Offline  Second
# 8   Daejeon   Online   First
# 9   Daejeon  Offline   First
# 10  Daejeon   Online  Second
# 11  Daejeon  Offline  Second

# %%
sns.relplot(
    data= facet_df,
    x='advertising',
    y='sales',
    hue='region',
    row='period',
    col='channel',
    kind='scatter'
)

# %%
sales_df = pd.DataFrame({
    "month": [
        1, 2, 3, 4, 5, 6,
        1, 2, 3, 4, 5, 6,
        1, 2, 3, 4, 5, 6,
    ],
    "region": [
        "Seoul", "Seoul", "Seoul",
        "Seoul", "Seoul", "Seoul",
        "Busan", "Busan", "Busan",
        "Busan", "Busan", "Busan",
        "Daejeon", "Daejeon", "Daejeon",
        "Daejeon", "Daejeon", "Daejeon",
    ],
    "sales": [
        120, 138, 155, 171, 188, 205,
        105, 118, 132, 149, 163, 178,
        92, 106, 119, 133, 148, 162,
    ],
    "advertising": [
        10, 12, 15, 18, 21, 24,
        9, 11, 13, 16, 19, 22,
        7, 9, 12, 14, 17, 20,
    ],
    "visitors": [
        800, 900, 1010, 1130, 1260, 1400,
        720, 810, 900, 1010, 1120, 1250,
        650, 730, 820, 910, 1020, 1140,
    ],
})

sales_df
# Out:
#     month   region  sales  advertising  visitors
# 0       1    Seoul    120           10       800
# 1       2    Seoul    138           12       900
# 2       3    Seoul    155           15      1010
# 3       4    Seoul    171           18      1130
# 4       5    Seoul    188           21      1260
# 5       6    Seoul    205           24      1400
# 6       1    Busan    105            9       720
# 7       2    Busan    118           11       810
# 8       3    Busan    132           13       900
# 9       4    Busan    149           16      1010
# 10      5    Busan    163           19      1120
# 11      6    Busan    178           22      1250
# 12      1  Daejeon     92            7       650
# 13      2  Daejeon    106            9       730
# 14      3  Daejeon    119           12       820
# 15      4  Daejeon    133           14       910
# 16      5  Daejeon    148           17      1020
# 17      6  Daejeon    162           20      1140

# %%
sns.set_theme()

sns.lineplot(data= sales_df,x='month',y='sales', hue='region',marker='o')
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %%
sns.set_theme(style='whitegrid',
              context='notebook',
              palette='deep')

sns.lineplot(data= sales_df,x='month',y='sales', hue='region',marker='o')
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %%
style = sns.axes_style()

style
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.8',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %% [markdown]
# style
# - darkgrid,whitegrid,dark,white,ticks
# context
# - paper, notebook, tahlk, poster
# color palette
# - 서로다른 범주 구분 : 범주형 팔레트
# - 작은 값에서 큰 값으로 변화 표현 : 연속형 팔레트
# - 특정 기준보다 낮거나 높은 방향 표현 : 발산형 팔레트

# %%
sns.color_palette(
    'deep',
    n_colors=6
)
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941)]

# %%
sns.color_palette(
    'pastel',
    6
)
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019)]

# %%
p= sns.color_palette(
    'muted',
    6
)
sns.palplot(p)

# %%
sns.set_theme(style='whitegrid',
              context='notebook',
              palette='pastel')

sns.lineplot(data= sales_df,x='month',y='sales', hue='region',marker='o')
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %%
sns.scatterplot(data= sales_df,x='month',y='sales', hue='region',palette='Set2', s=80)
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %% [markdown]
# 연속형 팔레트
# : 수치가 작은값에서 큰값으로 변화할떄 사용
#
# ex) 방문객 수가 증가할때 처럼 순서와 크기를 갖는 수치형 데이터

# %%
sns.scatterplot(data=sales_df, x= 'advertising', y='sales', hue='visitors', palette='rocket', s=100)
# Out:
# <Axes: xlabel='advertising', ylabel='sales'>

# %%
df = pd.DataFrame([[10,20,30],[20,40,60],[30,60,90]], index=['A','B','C'], columns=['X','Y','Z'])

sns.heatmap(data=df,annot=True, cmap='vlag')   #vlag,coolwarm
# Out:
# <Axes: >
