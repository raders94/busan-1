# %% [markdown]
# # 변수
#
# 변수는 메모리상 지정된 값을 가리키는 이름.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# 변수의 초기화
a = 10

# %% [markdown]
# a라는 변수에 10이라는 값을 할당

# %%
print(a)

# %% [markdown]
# 숫자와 특수 문자는 변수의 첫번째에 들어갈수 없다
# 예외 : _(언더바)
# 컴퓨터 연산은 위에서 아래로

# %%
mySmartIsSmart = False
#camel case
My_brother_is_smart = False
#snake case

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
