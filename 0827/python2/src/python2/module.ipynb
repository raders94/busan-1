# %% [markdown]
# # 모듈
#
# 프로그램이 커질수록 모든 코드를 하나의 파일에 담는것은 현실적으로 불가능하다.
# 때문애 모듈이라는 단위를 사용하며, 관련된 함수 등을 하나의 파일로 묶어서 재사용하고 구조적으로 관리할 수 있게 한다.

# %% [markdown]
# ## import
#
# 다른 모듈의 내용을 현재 코드에서 사용할 수있도록 불러오는 구문

# %%
import math as m
